# %% [markdown]
# ## Module End Project

# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# Out:
# C:\Users\Netcom\AppData\Local\Temp\ipykernel_3132\1624591944.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Dataset

# %%
df=pd.read_csv('myexcel.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Analysing the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     152     235
# 2   John Holland  Boston Celtics      30       SG   27     158     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     165     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     163     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     165     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     156     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26     176     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     151     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25     155     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  164.971616  221.543668  4.833970e+06
# std     15.966837    4.400128    8.618416   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.250000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  165.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  172.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df['Height'] = np.random.randint(150, 181, size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     152     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     165     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     163     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     165     203
# 454      Raul Neto       Utah Jazz      25       PG   24     156     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     176     256
# 456    Jeff Withey       Utah Jazz      24        C   26     151     231
# 457       Priyanka       Utah Jazz      34        C   25     155     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.fillna('Unknown')
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     165     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     152     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     165     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     163     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     165     203
# 454      Raul Neto       Utah Jazz      25       PG   24     156     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     176     256
# 456    Jeff Withey       Utah Jazz      24        C   26     151     231
# 457       Priyanka       Utah Jazz      34        C   25     155     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Categories with respect to team

# %%
grouped_by_team = df.groupby('Team')
for team, data in grouped_by_team:
    print(f"Team: {team}")
    print(data)
    print("\n")
# Out:
# Team: Atlanta Hawks
#                  Name           Team  Number Position  Age  Height  Weight  \
# 309     Kent Bazemore  Atlanta Hawks      24       SF   26     165     201
# 310  Tim Hardaway Jr.  Atlanta Hawks      10       SG   24     180     205
# 311      Kirk Hinrich  Atlanta Hawks      12       SG   35     157     190
# 312        Al Horford  Atlanta Hawks      15        C   30     161     245
# 313    Kris Humphries  Atlanta Hawks      43       PF   31     160     235
# 314       Kyle Korver  Atlanta Hawks      26       SG   35     164     212
# 315      Paul Millsap  Atlanta Hawks       4       PF   31     173     246
# 316      Mike Muscala  Atlanta Hawks      31       PF   24     159     240
# 317   Lamar Patterson  Atlanta Hawks      13       SG   24     170     225
# 318   Dennis Schroder  Atlanta Hawks      17       PG   22     150     172
# 319        Mike Scott  Atlanta Hawks      32       PF   27     153     237
# ...

# %% [markdown]
# ### Age $ Salary distribution of each team

# %%
grouped_by_team = df.groupby('Team')
team_stats = grouped_by_team.describe()

for team, data in grouped_by_team:
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    sns.histplot(data=data, x='Salary', bins=20, kde=True)
    plt.title(f'Salary Distribution - {team}')
    plt.xlabel('Salary')
    plt.ylabel('Count')
    plt.subplot(1, 2, 2)
    sns.histplot(data=data, x='Age', bins=20, kde=True)
    plt.title(f'Age Distribution - {team}')
    plt.xlabel('Age')
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Average Salary of each team

# %%
grouped_by_team = df.groupby('Team')
average_salary_by_team = grouped_by_team['Salary'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=average_salary_by_team.index, y=average_salary_by_team.values)
plt.title('Average Salary by Team')
plt.xlabel('Team')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1) How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
#1
T_C=df['Team'].value_counts()
T_C
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
percentage_splitting = (T_C / len(df)) * 100
percentage_splitting
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
plt.bar(percentage_splitting.index, percentage_splitting.values)
plt.xticks(rotation=90)
plt.xlabel('Teams')
plt.ylabel('Percentage')
plt.title('Percentage Split')
plt.show()

# %% [markdown]
# #### Data story:The highest percentage is in the team'New Orleans Pelicans'.

# %% [markdown]
# ### 2) Segregate the employees w.r.t different positions.

# %%
#2
position_counts = df['Position'].value_counts()
position_counts
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
group=df.groupby('Position')
grouped_to_string=df.groupby('Position')['Name'].apply(list).reset_index()
print(grouped_to_string)
# Out:
#   Position                                               Name
# 0        C  [Kelly Olynyk, Jared Sullinger, Tyler Zeller, ...
# 1       PF  [Jonas Jerebko, Amir Johnson, Jordan Mickey, C...
# 2       PG  [Avery Bradley, Terry Rozier, Marcus Smart, Is...
# 3       SF  [Jae Crowder, Thanasis Antetokounmpo, Carmelo ...
# 4       SG  [John Holland, R.J. Hunter, Evan Turner, James...

# %%
plt.figure(figsize=(5,5))
plt.bar(grouped_to_string['Position'],grouped_to_string['Name'].apply(len),color='r')
plt.xlabel('Position')
plt.ylabel('Employees Count')
plt.title('Number of Employees by Position')
plt.show()

# %% [markdown]
# #### Data Story: The highest number of employees is in the position 'SG'.

# %%
positions_order = ['SG', 'PF', 'PG', 'SF', 'C']
filtered_df=df.loc[df['Position'].isin(positions_order)]
filtered_df['Position'] = pd.Categorical(filtered_df['Position'], categories=positions_order, ordered=True)
filtered_df = filtered_df.sort_values(by='Position')
filtered_df
# Out:
#                     Name                   Team  Number Position  Age  Height  \
# 103            JJ Redick   Los Angeles Clippers       4       SG   31     158
# 226        Rashad Vaughn        Milwaukee Bucks      20       SG   19     165
# 158       Justin Holiday          Chicago Bulls       7       SG   27     165
# 89         Klay Thompson  Golden State Warriors      11       SG   26     166
# 380       Garrett Temple     Washington Wizards      17       SG   30     158
# ..                   ...                    ...     ...      ...  ...     ...
# 141  Willie Cauley-Stein       Sacramento Kings       0        C   22     170
# 143     DeMarcus Cousins       Sacramento Kings      15        C   25     161
# 147         Kosta Koufos       Sacramento Kings      41        C   27     151
# 321       Tiago Splitter          Atlanta Hawks      11        C   31     167
# 457             Priyanka              Utah Jazz      34        C   25     170
#
# ...

# %% [markdown]
# ### 3)Find from which age group most of the employees belong to.

# %%
#3
Age_counts = df['Age'].value_counts()
Age_counts
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Age',data=df)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #### Data Story:Most of the employees belongs to the age group 24.

# %% [markdown]
# ### 4) Find out under which team and position, spending in terms of salary is high.

# %%
#4
highest_salary = df['Salary'].idxmax()
highest_salary
# Out:
# 109

# %%
highest_salary_index = df['Salary'].idxmax()
highest_salary_amount = df.loc[highest_salary_index, 'Salary']
highest_salary_team = df.loc[highest_salary_index, 'Team']
highest_salary_position = df.loc[highest_salary_index, 'Position']

print('Highest Salary:', highest_salary_amount)
print('Team: ', highest_salary_team)
print('Position: ', highest_salary_position)
# Out:
# Highest Salary: 25000000.0
# Team:  Los Angeles Lakers
# Position:  SF

# %%
plt.bar(df['Team'],df['Salary'],color='blue',edgecolor='black')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Data Story: The highest salary is spend by the 'Team:  Los Angeles Lakers','Position: SG', and the Highest Salary is 25000000.0.

# %% [markdown]
# ### 5)Find if there is any correlation between age and salary , represent it visually.

# %%
#5
correlation = df['Age'].corr(df['Salary'])
sns.boxplot(x='Age',y='Salary',data=df)
plt.title('Correlation between Age and Salary')
plt.show()

# %% [markdown]
# #### Data Story: The  correlation between age and salary gives the information that the age group of 37 is highly correlated.
